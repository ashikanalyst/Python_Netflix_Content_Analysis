# %%
# Importing Liabraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = pd.read_csv("D:/Data Analyst/project/Python_Netflix_Content_Analysis/dataset/netflix_titles.csv")

# Data Cleanup
df['date_added'] = pd.to_datetime(df['date_added'].str.strip(), errors='coerce')
df['rating'] = df['rating'].fillna("Unknown")

# %%
# Extract Year Column
df['year_added'] = df['date_added'].dt.year.astype('Int64')

# %%
df_type_count = df.groupby(['year_added', 'type']).size().unstack(fill_value=0)
df_type_count
# Out:
# type        Movie  TV Show
# year_added
# 2008            1        1
# 2009            2        0
# 2010            1        0
# 2011           13        0
# 2012            3        0
# 2013            6        5
# 2014           19        5
# 2015           56       26
# 2016          253      176
# 2017          839      349
# 2018         1237      412
# 2019         1424      592
# 2020         1284      595
# 2021          993      505

# %%
plt.figure(figsize=(10, 5))

sns.lineplot(
    data=df_type_count,
    palette='tab10',
    linewidth=2, 
    marker='o', 
    markersize=6
)

plt.title('Netflix Content Growth Over Time', fontsize=14, fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.legend(title='Type')

plt.tight_layout()
plt.show()
